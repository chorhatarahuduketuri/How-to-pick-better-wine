# %% [markdown]
# # EDA

# %% [markdown]
# ## Imports and data loading

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data loading
redwine = pd.read_csv('../data/winequality-red.csv', delimiter=';')
whitewine = pd.read_csv('../data/winequality-white.csv', delimiter=';')

# %% [markdown]
# ## Initial look
# - Note: Since there are two datasets, everything will get done twice.
# - Note: The data taken from the UCI Machine Learning Repository is already cleaned and has no missing values. This data was downloaded on 06/09/2018 from https://archive.ics.uci.edu/ml/datasets/wine+quality.
# - Note: requested citation by dataset providers:
# > P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis.
# >Modeling wine preferences by data mining from physicochemical properties. In Decision Support Systems, Elsevier, 47(4):547-553, 2009.
#
# First, the features.
# There are 11 features, and 1 target.
# The target is `quality`, and is on a 0-10 integer scale.
# The features are:
# 1. `fixed acidity`
# 2. `volatile acidity`
# 3. `citric acid`
# 4. `residual sugar`
# 5. `chlorides`
# 6. `free sulfur dioxide`
# 7. `total sulfur dioxide`
# 8. `density`
# 9. `pH`
# 10. `sulphates`
# 11. `alcohol`
#
# It should also be noted that I don't actually know what most of the features really are. I understand the `quality` metric, that is both explained and obvious. `alcohol` I understand to be the percentage of the wine by volume that is alcohol. `citric acid` - citrus fruit. `pH` I remember from school. But `sulphates`? What are those? The difference between `fixed acidity` and `volatile acidity`? I don't know what either of them are as it is. `density`? By what measure? Compared to what? Some of the `density` readings are >1, what does that mean relative to densities <1? Or =1?
#
# I don't know what they mean, and for the purposes of answering the question-objectives, I don't need to. However, if they were much more specific I would likely require more knowledge or help from someone with more knowledge than I have.
#
# Second, a quick look at the data itself, and a statistical summary of it.

# %%
redwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
redwine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
whitewine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
whitewine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# What's interesting about the above numbers isn't so much what they are for each dataset, but how they're similar or different between the datasets.
#
# Red wine has both higher fixed acidity and is more varied in it's fixed acidity. White wine has both more residual sugar, and much greater variance in it's residual sugar. The alcohol content is very similar between the two, especially in mean. The mean and the variability of white wine are both greater than those of red wine, but only by a small amount.
#
# This means that there are meaningful differences between the two datasets, and that they can't just be combined naively - at minimum the colour of the wine would need to be added as a categorical feature.

# %%
# Quality
fig1, axarr1 = plt.subplots(1, 2, figsize=(16, 8))
redwine['quality'].value_counts().sort_index().plot.bar(ax=axarr1[0], title='Red wine quality counts')
whitewine['quality'].value_counts().sort_index().plot.bar(ax=axarr1[1], title='White wine quality counts')

# %% [markdown]
# It's interesting to note that none of the wines scored 10, or below 3. And there were no 9s for red. Instead of 0-10 this could easily have been a 1-7 scale, and these graphs make it look like most wines would be 2-3/7, which would move the means from just above the middle of the scale, to just below the middle of the scale.
#
# As well as that, the difference in the numbers between the means of red and white is ~0.24, which doesn't sound like a lot. Looking at the charts above though, it feels like a lot more. White clearly has proportionally more 6s, 7s, and 8s than red.

# %% [markdown]
# ## Feature investigation

# %%
redwine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
whitewine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# Correlation
fig2, axarr2 = plt.subplots(1, 2, figsize=(16, 8))
sns.heatmap(redwine.corr(), square=True, center=0, ax=axarr2[0])
sns.heatmap(whitewine.corr(), square=True, center=0, ax=axarr2[1])

# %% [markdown]
# This is a graph of correlation between all the different features in the dataset. The brighter the colour between two features, the more useful they are in predicting each other. Note that negative correlation is still useful; it still indicates something about the other. It's zero correlation that's useless - that means that they provide no information about each other.
#
# Quality doesn't appear to have a strong linear correlation with any other feature, ~0.44 with alcohol being the strongest. Hopefully it will have some non-linear or multivariate correlation.
#
# Now that the data has been looked at in general and nothing significant has been found, it's time to head towards the answer-objectives.
